# %%
from perekrestok_parser import PerekrestokScraper
from magnit_parser import MagnitScraper
import pandas as pd

import multiprocessing

# %%
def scrape_perekrestok():
    perekrestok_scraper = PerekrestokScraper()
    perekrestok_df = perekrestok_scraper.scrape_data()
    perekrestok_df.to_parquet('perekrestok.parquet')

def scrape_magnit():
    magnit_scraper = MagnitScraper()
    res_magnit = magnit_scraper.scrape_data()
    res_magnit.to_parquet('res_magnit.parquet')

if __name__ == '__main__':
    perekrestok_process = multiprocessing.Process(target=scrape_perekrestok)
    magnit_process = multiprocessing.Process(target=scrape_magnit)

    perekrestok_process.start()
    magnit_process.start()

    perekrestok_process.join()
    magnit_process.join()
# Out:
# [37277, 37651, 37653] was scrapped
# [37655, 37657, 37659] was scrapped
# {'cat_title': 'Ягоды', 'cat_url': 'https://www.perekrestok.ru/cat/c/154/agody'} was scraped
# {'cat_title': 'Творожки', 'cat_url': 'https://www.perekrestok.ru/cat/c/657/tvorozki'} was scraped
# [38699, 38705, 38707] was scrapped
# {'cat_title': 'Bonte', 'cat_url': 'https://www.perekrestok.ru/cat/c/291/bonte'} was scraped
# {'cat_title': 'Первые блюда', 'cat_url': 'https://www.perekrestok.ru/cat/c/31/pervye-bluda'} was scraped
# {'cat_title': 'Начос', 'cat_url': 'https://www.perekrestok.ru/cat/c/774/nacos'} was scraped
# [38715, 38711, 38721] was scrapped
# {'cat_title': 'Меню на праздники', 'cat_url': 'https://www.perekrestok.ru/cat/c/1096/menu-na-prazdniki'} was scraped
# [38391, 16869, 38555] was scrapped
# [16849, 38393, 37465] was scrapped
# [26995, 4854, 4840] was scrapped
# {'cat_title': 'Kokoro', 'cat_url': 'https://www.perekrestok.ru/cat/c/292/kokoro'} was scraped
# {'cat_title': 'Зелень и салаты', 'cat_url': 'https://www.perekrestok.ru/cat/c/151/zelen-i-salaty'} was scraped
# [4844, 17627, 17487] was scrapped
# {'cat_title': 'Закуски', 'cat_url': 'https://www.perekrestok.ru/cat/c/307/zakuski'} was scraped
# {'cat_title': 'Десерты и снеки', 'cat_url': 'https://www.perekrestok.ru/cat/c/658/deserty-i-sneki'} was scraped
# {'cat_title': 'Снеки', 'cat_url': 'https://www.perekrestok.ru/cat/c/709/sneki'} was scraped
# {'cat_title': 'Съешь меня', 'cat_url': 'https://www.perekrestok.ru/cat/c/302/ses-mena'} was scraped
# [4838, 4835, 4839] was scrapped
# [4836, 38545, 16967] was scrapped
# {'cat_title': 'Грибы', 'cat_url': 'https://www.perekrestok.ru/cat/c/155/griby'} was scraped
# {'cat_title': 'Закуски к столу', 'cat_url': 'https://www.perekrestok.ru/cat/c/1097/zakuski-k-stolu'} was scraped
# {'cat_title': 'Honey Kid', 'cat_url': 'https://www.perekrestok.ru/cat/c/301/honey-kid'} was scraped
# [4851, 4847, 4848] was scrapped
# {'cat_title': 'Яйца', 'cat_url': 'https://www.perekrestok.ru/cat/c/123/ajca'} was scraped
# {'cat_title': 'Десерты', 'cat_url': 'https://www.perekrestok.ru/cat/c/26/deserty'} was scraped
# {'cat_title': 'Соломки', 'cat_url': 'https://www.perekrestok.ru/cat/c/714/solomki'} was scraped
# {'cat_title': 'Основные блюда', 'cat_url': 'https://www.perekrestok.ru/cat/c/30/osnovnye-bluda'} was scraped
# [26739, 4999, 5001] was scrapped
# {'cat_title': 'Кисломолочные продукты', 'cat_url': 'https://www.perekrestok.ru/cat/c/120/kislomolocnye-produkty'} was scraped
# [5003, 38287, 5009] was scrapped
# [18615, 18477, 4460] was scrapped
# {'cat_title': 'Бобовые', 'cat_url': 'https://www.perekrestok.ru/cat/c/745/bobovye'} was scraped
# {'cat_title': 'Хлебные палочки', 'cat_url': 'https://www.perekrestok.ru/cat/c/715/hlebnye-palocki'} was scraped
# [38553, 18475, 4467] was scrapped
# {'cat_title': 'Напитки', 'cat_url': 'https://www.perekrestok.ru/cat/c/28/napitki'} was scraped
# [38395, 7197, 5016] was scrapped
# {'cat_title': 'Премиум меню', 'cat_url': 'https://www.perekrestok.ru/cat/c/1046/premium-menu'} was scraped
# [7211, 16979, 7203] was scrapped
# {'cat_title': 'Сметана', 'cat_url': 'https://www.perekrestok.ru/cat/c/118/smetana'} was scraped
# [5014, 5013, 5012] was scrapped
# {'cat_title': 'Сухари', 'cat_url': 'https://www.perekrestok.ru/cat/c/716/suhari'} was scraped
# [12787, 12785, 12783] was scrapped
# {'cat_title': 'Соусы', 'cat_url': 'https://www.perekrestok.ru/cat/c/1090/sousy'} was scraped
# [12791, 38731, 12767] was scrapped
# {'cat_title': 'Специи, приправы и пряности', 'cat_url': 'https://www.perekrestok.ru/cat/c/103/specii-pripravy-i-pranosti'} was scraped
# {'cat_title': 'Сэндвичи и шаурма', 'cat_url': 'https://www.perekrestok.ru/cat/c/306/sendvici-i-saurma'} was scraped
# [5280, 38807, 5279] was scrapped
# [7157, 4875, 26777] was scrapped
# {'cat_title': 'Сливки', 'cat_url': 'https://www.perekrestok.ru/cat/c/115/slivki'} was scraped
# [26877, 4883, 7764] was scrapped
# {'cat_title': 'Хлебцы', 'cat_url': 'https://www.perekrestok.ru/cat/c/717/hlebcy'} was scraped
# {'cat_title': 'Мука', 'cat_url': 'https://www.perekrestok.ru/cat/c/106/muka'} was scraped
# {'cat_title': 'Молоко', 'cat_url': 'https://www.perekrestok.ru/cat/c/114/moloko'} was scraped
# {'cat_title': 'Молочные консервы', 'cat_url': 'https://www.perekrestok.ru/cat/c/124/molocnye-konservy'} was scraped
# {'cat_title': 'Водоросли', 'cat_url': 'https://www.perekrestok.ru/cat/c/718/vodorosli'} was scraped
# [23191, 23187, 23193] was scrapped
# {'cat_title': 'Весовая кулинария', 'cat_url': 'https://www.perekrestok.ru/cat/c/296/vesovaa-kulinaria'} was scraped
# [23195, 23199, 23201] was scrapped
# [23239, 23243, 23237] was scrapped
# {'cat_title': 'Компоненты для выпечки', 'cat_url': 'https://www.perekrestok.ru/cat/c/102/komponenty-dla-vypecki'} was scraped
# [23249, 23251, 23241] was scrapped
# {'cat_title': 'Молочные коктейли', 'cat_url': 'https://www.perekrestok.ru/cat/c/116/molocnye-koktejli'} was scraped
# {'cat_title': 'Суши и роллы', 'cat_url': 'https://www.perekrestok.ru/cat/c/298/susi-i-rolly'} was scraped
# [23247, 23245, 23235] was scrapped
# {'cat_title': 'Сыр', 'cat_url': 'https://www.perekrestok.ru/cat/c/122/syr'} was scraped
# {'cat_title': 'Печенье', 'cat_url': 'https://www.perekrestok.ru/cat/c/197/pecene'} was scraped
# {'cat_title': 'Соль', 'cat_url': 'https://www.perekrestok.ru/cat/c/101/sol'} was scraped
# [23285, 23287, 23289] was scrapped
# [23293, 23291, 12437] was scrapped
# [12439, 12541, 38661] was scrapped
# [12441, 12547, 12697] was scrapped
# {'cat_title': 'Творог', 'cat_url': 'https://www.perekrestok.ru/cat/c/117/tvorog'} was scraped
# [35725, 35727, 35729] was scrapped
# {'cat_title': 'Овощи', 'cat_url': 'https://www.perekrestok.ru/cat/c/150/ovosi'} was scraped
# {'cat_title': 'Завтрак', 'cat_url': 'https://www.perekrestok.ru/cat/c/27/zavtrak'} was scraped
# {'cat_title': 'Зелёная Линия', 'cat_url': 'https://www.perekrestok.ru/cat/c/284/zelenaa-linia'} was scraped
# [35731, 35733, 35735] was scrapped
# {'cat_title': 'Вафли', 'cat_url': 'https://www.perekrestok.ru/cat/c/702/vafli'} was scraped
# [37219, 37253, 37217] was scrapped
# [37235, 7497, 7494] was scrapped
# {'cat_title': 'Чипсы', 'cat_url': 'https://www.perekrestok.ru/cat/c/202/cipsy'} was scraped
# [7722, 7633, 27729] was scrapped
# {'cat_title': 'Леденцы', 'cat_url': 'https://www.perekrestok.ru/cat/c/194/ledency'} was scraped
# [28609, 28005, 28031] was scrapped
# {'cat_title': 'Сырки', 'cat_url': 'https://www.perekrestok.ru/cat/c/656/syrki'} was scraped
# [7775, 11953, 16551] was scrapped
# {'cat_title': 'Фрукты', 'cat_url': 'https://www.perekrestok.ru/cat/c/153/frukty'} was scraped
# [16553, 16555, 39231] was scrapped
# [36981, 36985, 23519] was scrapped
# {'cat_title': 'Пряники', 'cat_url': 'https://www.perekrestok.ru/cat/c/703/praniki'} was scraped
# [36979, 34757, 19671] was scrapped
# {'cat_title': 'Безалкогольное вино', 'cat_url': 'https://www.perekrestok.ru/cat/c/739/bezalkogolnoe-vino'} was scraped
# {'cat_title': 'Маркет', 'cat_url': 'https://www.perekrestok.ru/cat/c/287/market'} was scraped
# [36977, 28369, 28623] was scrapped
# [27771, 32873, 18465] was scrapped
# {'cat_title': 'Драже', 'cat_url': 'https://www.perekrestok.ru/cat/c/707/draze'} was scraped
# [32957, 28583, 4518] was scrapped
# [36927, 36823, 4334] was scrapped
# [27635, 37189, 27639] was scrapped
# {'cat_title': 'Хлебцы', 'cat_url': 'https://www.perekrestok.ru/cat/c/245/hlebcy'} was scraped
# {'cat_title': 'Смузи', 'cat_url': 'https://www.perekrestok.ru/cat/c/213/smuzi'} was scraped
# [34749, 37181, 33209] was scrapped
# [7668, 37295, 37293] was scrapped
# {'cat_title': 'Йогурты', 'cat_url': 'https://www.perekrestok.ru/cat/c/119/jogurty'} was scraped
# {'cat_title': 'Мarket Соllection', 'cat_url': 'https://www.perekrestok.ru/cat/c/290/market-sollection'} was scraped
# [7688, 7652, 18723] was scrapped
# {'cat_title': 'Шоколад', 'cat_url': 'https://www.perekrestok.ru/cat/c/195/sokolad'} was scraped
# [37297, 28489, 28477] was scrapped
# {'cat_title': 'Восточные сладости, халва', 'cat_url': 'https://www.perekrestok.ru/cat/c/188/vostocnye-sladosti-halva'} was scraped
# [28491, 28483, 28487] was scrapped
# {'cat_title': 'Сокосодержащие напитки', 'cat_url': 'https://www.perekrestok.ru/cat/c/740/sokosoderzasie-napitki'} was scraped
# {'cat_title': 'Паштеты', 'cat_url': 'https://www.perekrestok.ru/cat/c/778/pastety'} was scraped
# [28485, 28481, 4251] was scrapped
# {'cat_title': 'Хлебобулочные изделия', 'cat_url': 'https://www.perekrestok.ru/cat/c/246/hlebobulocnye-izdelia'} was scraped
# [4301, 27523, 33379] was scrapped
# {'cat_title': 'Жевательная резинка', 'cat_url': 'https://www.perekrestok.ru/cat/c/190/zevatelnaa-rezinka'} was scraped
# {'cat_title': 'Батончики', 'cat_url': 'https://www.perekrestok.ru/cat/c/203/batonciki'} was scraped
# [5142, 28643, 5233] was scrapped
# {'cat_title': 'Заливное', 'cat_url': 'https://www.perekrestok.ru/cat/c/781/zalivnoe'} was scraped
# {'cat_title': 'Энергетические напитки', 'cat_url': 'https://www.perekrestok.ru/cat/c/206/energeticeskie-napitki'} was scraped
# [5148, 5128, 28641] was scrapped
# [7803, 7729, 7766] was scrapped
# {'cat_title': 'Шеф Перекрёсток', 'cat_url': 'https://www.perekrestok.ru/cat/c/283/sef-perekrestok'} was scraped
# {'cat_title': 'Шоколадные и ореховые пасты', 'cat_url': 'https://www.perekrestok.ru/cat/c/204/sokoladnye-i-orehovye-pasty'} was scraped
# {'cat_title': 'Морсы', 'cat_url': 'https://www.perekrestok.ru/cat/c/214/morsy'} was scraped
# [5087, 5083, 5086] was scrapped
# [5085, 5084, 5037] was scrapped
# {'cat_title': 'Мороженое', 'cat_url': 'https://www.perekrestok.ru/cat/c/321/morozenoe'} was scraped
# {'cat_title': 'Студни', 'cat_url': 'https://www.perekrestok.ru/cat/c/779/studni'} was scraped
# {'cat_title': 'Кисели', 'cat_url': 'https://www.perekrestok.ru/cat/c/742/kiseli'} was scraped
# [27775, 27905, 27815] was scrapped
# [5171, 28453, 27977] was scrapped
# [5150, 4363, 27125] was scrapped
# {'cat_title': 'Компоты', 'cat_url': 'https://www.perekrestok.ru/cat/c/743/kompoty'} was scraped
# [27127, 27129, 27131] was scrapped
# {'cat_title': 'Молочный Знак', 'cat_url': 'https://www.perekrestok.ru/cat/c/322/molocnyj-znak'} was scraped
# {'cat_title': 'Конфеты', 'cat_url': 'https://www.perekrestok.ru/cat/c/193/konfety'} was scraped
# {'cat_title': 'Шашлык', 'cat_url': 'https://www.perekrestok.ru/cat/c/951/saslyk'} was scraped
# {'cat_title': 'Настойки', 'cat_url': 'https://www.perekrestok.ru/cat/c/8/nastojki'} was scraped
# {'cat_title': 'Для мебели и ковров', 'cat_url': 'https://www.perekrestok.ru/cat/c/266/dla-mebeli-i-kovrov'} was scraped
# {'cat_title': 'Стики', 'cat_url': 'https://www.perekrestok.ru/cat/c/250/stiki'} was scraped
# {'cat_title': 'Джин', 'cat_url': 'https://www.perekrestok.ru/cat/c/10/dzin'} was scraped
# {'cat_title': 'Устройства', 'cat_url': 'https://www.perekrestok.ru/cat/c/249/ustrojstva'} was scraped
# {'cat_title': 'Предметы для уборки', 'cat_url': 'https://www.perekrestok.ru/cat/c/241/predmety-dla-uborki'} was scraped
# {'cat_title': 'Бренди', 'cat_url': 'https://www.perekrestok.ru/cat/c/14/brendi'} was scraped
# {'cat_title': 'Ликёры', 'cat_url': 'https://www.perekrestok.ru/cat/c/16/likery'} was scraped
# {'cat_title': 'Сервировка', 'cat_url': 'https://www.perekrestok.ru/cat/c/166/servirovka'} was scraped
# {'cat_title': 'Автоаксессуары', 'cat_url': 'https://www.perekrestok.ru/cat/c/48/avtoaksessuary'} was scraped
# {'cat_title': 'Вермут', 'cat_url': 'https://www.perekrestok.ru/cat/c/764/vermut'} was scraped
# {'cat_title': 'Бальзам', 'cat_url': 'https://www.perekrestok.ru/cat/c/17/balzam'} was scraped
# {'cat_title': 'Декор и интерьер', 'cat_url': 'https://www.perekrestok.ru/cat/c/45/dekor-i-interer'} was scraped
# {'cat_title': 'Кружки, стаканы, бокалы', 'cat_url': 'https://www.perekrestok.ru/cat/c/164/kruzki-stakany-bokaly'} was scraped
# {'cat_title': 'Наборы для специй', 'cat_url': 'https://www.perekrestok.ru/cat/c/167/nabory-dla-specij'} was scraped
# {'cat_title': 'Спорт и туризм', 'cat_url': 'https://www.perekrestok.ru/cat/c/51/sport-i-turizm'} was scraped
# {'cat_title': 'Всё для хранения', 'cat_url': 'https://www.perekrestok.ru/cat/c/36/vse-dla-hranenia'} was scraped
# {'cat_title': 'Одежда, обувь, аксессуары', 'cat_url': 'https://www.perekrestok.ru/cat/c/43/odezda-obuv-aksessuary'} was scraped
# {'cat_title': 'Всё для дачи и сада', 'cat_url': 'https://www.perekrestok.ru/cat/c/38/vse-dla-daci-i-sada'} was scraped
# {'cat_title': 'Мелочи для дома', 'cat_url': 'https://www.perekrestok.ru/cat/c/47/meloci-dla-doma'} was scraped
# {'cat_title': 'Галантерейные аксессуары', 'cat_url': 'https://www.perekrestok.ru/cat/c/40/galanterejnye-aksessuary'} was scraped
# {'cat_title': 'Техника и аксессуары', 'cat_url': 'https://www.perekrestok.ru/cat/c/46/tehnika-i-aksessuary'} was scraped
# {'cat_title': 'Товары для бани и сауны', 'cat_url': 'https://www.perekrestok.ru/cat/c/52/tovary-dla-bani-i-sauny'} was scraped
# {'cat_title': 'Всё для праздника', 'cat_url': 'https://www.perekrestok.ru/cat/c/42/vse-dla-prazdnika'} was scraped
# {'cat_title': 'Канцелярия', 'cat_url': 'https://www.perekrestok.ru/cat/c/53/kancelaria'} was scraped
# {'cat_title': 'Вино', 'cat_url': 'https://www.perekrestok.ru/cat/c/2/vino'} was scraped
# {'cat_title': 'Игристые вина', 'cat_url': 'https://www.perekrestok.ru/cat/c/3/igristye-vina'} was scraped
# {'cat_title': 'Виски, бурбон', 'cat_url': 'https://www.perekrestok.ru/cat/c/5/viski-burbon'} was scraped
# {'cat_title': 'Коньяк', 'cat_url': 'https://www.perekrestok.ru/cat/c/4/konak'} was scraped

# %%
magnit_prod = pd.read_parquet('res_magnit.parquet')
magnit_cat = pd.read_parquet('magnit_categories.parquet')
perekrestok_prod = pd.read_parquet('perekrestok.parquet')

m1 = magnit_cat.iloc[:, :3].drop_duplicates()
m1.columns = ['cat_id', 'cat_name',  'cat_code']
m2 = magnit_cat.iloc[:, 3:6].drop_duplicates()
m2.columns = ['cat_id', 'cat_name',  'cat_code']
m3 = magnit_cat.iloc[:, 6:9].drop_duplicates()  
m3.columns = ['cat_id', 'cat_name',  'cat_code']
magnit_catgs = pd.concat([m1,m2,m3], ignore_index=True)

# %%
prod_magnit = pd.json_normalize(magnit_prod.explode('offers').to_dict(orient='records'))[['categories', 'code', 'grammar', 'id', 'isForAdults', 'name',
       'unitValue', 'offers.price',
       'offers.quantity']].explode('categories')
prod_magnit['offers.price'] = prod_magnit['offers.price'].str.replace(',','.').astype(float)
prod_cat_magnit = prod_magnit.merge(
    magnit_catgs[magnit_catgs.cat_name.notna()],
    how='left',
    left_on='categories',
    right_on='cat_id'
)

# %%
magnit_cat_avg = prod_cat_magnit.groupby('cat_name').agg({'offers.price':'mean'}).reset_index()
magnit_cat_avg.columns = ['category', 'avg_price']

# %%
perekrestok_prod['product_price'] = perekrestok_prod['product_price'].str.replace(',','.').str.split('₽').str[0].str.replace(' ','').astype(float)
perekrestok_cat_avg = perekrestok_prod.groupby('cat_title').agg({'product_price':'mean'}).reset_index()
perekrestok_cat_avg.columns = ['category', 'avg_price']

# %%
all_cats = perekrestok_cat_avg.merge(magnit_cat_avg, on='category', how='outer', suffixes=('_perekrestok', '_magnit'))
cats_mapped = all_cats[(all_cats.avg_price_perekrestok.isna()==False)&(all_cats.avg_price_magnit.isna()==False)]

# %%
perekrestok_unmapped = perekrestok_cat_avg[~perekrestok_cat_avg.category.isin(cats_mapped.category.values)]
magnit_unmapped = magnit_cat_avg[~magnit_cat_avg.category.isin(cats_mapped.category.values)]

# %%
from fuzzywuzzy import fuzz
#fuzz.partial_ratio('Автомасла', perekrestok_unmapped.category.values)

mapped_cats = []
for target_word in magnit_unmapped.category.values:
    target = 70

    best_match = None
    best_partial_ratio = 0
    best_matchs = {}
    for word in perekrestok_unmapped.category.values:
        #print(word)
        partial_ratio = fuzz.token_set_ratio(target_word, word)
        if partial_ratio > best_partial_ratio:
            #print(target_word, word,partial_ratio)
            best_partial_ratio = partial_ratio
            best_match = word
            #best_matchs[word] = best_partial_ratio

    if best_partial_ratio>=target:
        best_matchs['perekrestok'] = best_match
        best_matchs['magnit'] = target_word
    else:
        best_matchs['perekrestok'] = None
        best_matchs['magnit'] = target_word
    mapped_cats.append(best_matchs)

# %%
magnit_mapped = pd.DataFrame(mapped_cats).merge(magnit_unmapped, left_on='magnit', right_on='category', how='outer').rename({'avg_price':'avg_price_magnit'}, axis=1)
all_unmapped_mapped = magnit_mapped.merge(perekrestok_unmapped, left_on='perekrestok', right_on='category', how='outer').rename({'avg_price':'avg_price_perekrestok'}, axis=1)
#all_unmapped_mapped[(all_unmapped_mapped.avg_price_perekrestok.isna()==False)&(all_unmapped_mapped.avg_price_magnit.isna()==False)]

# %%
all_unmapped_mapped = all_unmapped_mapped[['magnit','avg_price_magnit','category_y','avg_price_perekrestok']].rename({'category_y':'perekrestok'}, axis=1)

cats_mapped['magnit'] = cats_mapped.category
cats_mapped['perekrestok'] = cats_mapped.category
cats_mapped = cats_mapped.drop('category', axis=1)

import numpy as np
all_mapped_categories = pd.concat([all_unmapped_mapped, cats_mapped])
all_mapped_categories['difference'] = np.where(all_mapped_categories['avg_price_magnit'].isna() | all_mapped_categories['avg_price_perekrestok'].isna(), 0, all_mapped_categories['avg_price_magnit'] - all_mapped_categories['avg_price_perekrestok'])
all_mapped_categories = all_mapped_categories.sort_values('difference', ascending=False).reset_index(drop=True)
# Out:
# /tmp/ipykernel_56460/2990299848.py:1: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipykernel_56460/2990299848.py:2: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# Out:
#                magnit  avg_price_magnit perekrestok  avg_price_perekrestok  \
# 0           Автомасла       1363.073333         NaN                    NaN
# 1           Автохимия        238.188430         NaN                    NaN
# 2    Аптечки дорожные        509.990000         NaN                    NaN
# 3            Бассейны        699.990000         NaN                    NaN
# 4        Безопасность        372.847143         NaN                    NaN
# ..                ...               ...         ...                    ...
# 266              Фарш        161.823333        Фарш             234.241310
# 269            Фрукты        171.021053      Фрукты             288.945645
# 273            Хлебцы         92.444545      Хлебцы              99.534323
# 279             Чипсы         91.061429       Чипсы             140.026802
# 288             Ягоды        414.980000       Ягоды             450.251800
#
#      difference
# 0      0.000000
# 1      0.000000
# 2      0.000000
# 3      0.000000
# 4      0.000000
# ..          ...
# 266  -72.417977
# 269 -117.924592
# 273   -7.089778
# 279  -48.965374
# 288  -35.271800
#
# [388 rows x 5 columns]

# %%
import dash
import dash_core_components as dcc
import dash_html_components as html
from dash.dependencies import Input, Output
import pandas as pd


df = all_mapped_categories

app = dash.Dash(__name__)

# App layout
app.layout = html.Div([
    dcc.Dropdown(
        id='magnit-category-dropdown',
        options=[{'label': category, 'value': category} for category in df['magnit'].dropna().unique()],
        multi=True,
        placeholder='Select magnit categories'
    ),
    html.Br(),
    dcc.Dropdown(
        id='perekrestok-category-dropdown',
        options=[{'label': category, 'value': category} for category in df['perekrestok'].dropna().unique()],
        multi=True,
        placeholder='Select perekrestok categories'
    ),
    html.Br(),
    html.Div([
        dcc.Input(
            id='avg-price-magnit-filter',
            type='number',
            placeholder='Filter by avg price (magnit)',
            debounce=True
        ),
        dcc.Dropdown(
            id='avg-price-magnit-operator',
            options=[
                {'label': '=', 'value': 'eq'},
                {'label': '>', 'value': 'gt'},
                {'label': '<', 'value': 'lt'},
            ],
            value='eq',
            clearable=False,
        ),
    ]),
    html.Br(),
    html.Div([
        dcc.Input(
            id='avg-price-perekrestok-filter',
            type='number',
            placeholder='Filter by avg price (perekrestok)',
            debounce=True
        ),
        dcc.Dropdown(
            id='avg-price-perekrestok-operator',
            options=[
                {'label': '=', 'value': 'eq'},
                {'label': '>', 'value': 'gt'},
                {'label': '<', 'value': 'lt'},
            ],
            value='eq',
            clearable=False,
        ),
    ]),
    html.Br(),
    html.Div([
        dcc.Input(
            id='difference-filter',
            type='number',
            placeholder='Filter by difference',
            debounce=True
        ),
        dcc.Dropdown(
            id='difference-operator',
            options=[
                {'label': '=', 'value': 'eq'},
                {'label': '>', 'value': 'gt'},
                {'label': '<', 'value': 'lt'},
            ],
            value='eq',
            clearable=False,
        ),
    ]),
    html.Br(),
    html.Table(id='filtered-table'),
])

@app.callback(
    Output('filtered-table', 'children'),
    Input('magnit-category-dropdown', 'value'),
    Input('perekrestok-category-dropdown', 'value'),
    Input('avg-price-magnit-filter', 'value'),
    Input('avg-price-magnit-operator', 'value'),
    Input('avg-price-perekrestok-filter', 'value'),
    Input('avg-price-perekrestok-operator', 'value'),
    Input('difference-filter', 'value'),
    Input('difference-operator', 'value')
)
def update_table(magnit_selected_categories, perekrestok_selected_categories, avg_price_magnit_filter,
                 avg_price_magnit_operator, avg_price_perekrestok_filter, avg_price_perekrestok_operator, difference_filter,
                 difference_operator):
    filtered_df = df.copy()

    if magnit_selected_categories:
        filtered_df = filtered_df[filtered_df['magnit'].isin(magnit_selected_categories)]
    if perekrestok_selected_categories:
        filtered_df = filtered_df[filtered_df['perekrestok'].isin(perekrestok_selected_categories)]
    if avg_price_magnit_filter is not None:
        if avg_price_magnit_operator == 'eq':
            filtered_df = filtered_df[filtered_df['avg_price_magnit'] == avg_price_magnit_filter]
        elif avg_price_magnit_operator == 'gt':
            filtered_df = filtered_df[filtered_df['avg_price_magnit'] > avg_price_magnit_filter]
        elif avg_price_magnit_operator == 'lt':
            filtered_df = filtered_df[filtered_df['avg_price_magnit'] < avg_price_magnit_filter]
    if avg_price_perekrestok_filter is not None:
        if avg_price_perekrestok_operator == 'eq':
            filtered_df = filtered_df[filtered_df['avg_price_perekrestok'] == avg_price_perekrestok_filter]
        elif avg_price_perekrestok_operator == 'gt':
            filtered_df = filtered_df[filtered_df['avg_price_perekrestok'] > avg_price_perekrestok_filter]
        elif avg_price_perekrestok_operator == 'lt':
            filtered_df = filtered_df[filtered_df['avg_price_perekrestok'] < avg_price_perekrestok_filter]
    if difference_filter is not None:
        if difference_operator == 'eq':
            filtered_df = filtered_df[filtered_df['difference'] == difference_filter]
        elif difference_operator == 'gt':
            filtered_df = filtered_df[filtered_df['difference'] > difference_filter]
        elif difference_operator == 'lt':
            filtered_df = filtered_df[filtered_df['difference'] < difference_filter]

    return [
        html.Tr([html.Th(col) for col in filtered_df.columns])] + [
        html.Tr([html.Td(filtered_df.iloc[i][col]) for col in filtered_df.columns]) for i in range(len(filtered_df))
    ]

if __name__ == '__main__':
    app.run_server(debug=True)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
#проблемы: не учитывается вес, размер, количество юнитов, нужно приводить к единому измерению (930мл превращать в 1000мл итд)
